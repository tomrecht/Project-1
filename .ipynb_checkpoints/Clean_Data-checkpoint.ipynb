# %%
# Dependencies
from census import Census
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

# %%
# Census API Key
census_api_key = "85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98"

# %%
def census(c,year):
    census_data = c.acs5.get(("NAME", "B16001_002E", "B16001_003E", "B16001_009E",
                          "B16001_021E","B16001_009E","B16001_012E","B16001_015E","B16001_018E",
                          "B16001_030E","B16001_033E","B16001_036E","B16001_039E","B16001_045E",
                          "B16001_048E","B16001_051E","B16001_054E","B16001_057E","B16001_066E",
                          "B16001_069E","B16001_072E","B16001_075E","B16001_078E","B16001_081E",
                          "B16001_084E","B16001_087E","B16001_093E","B16001_099E","B16001_105E",
                          "B16001_105E","B16001_108E","B16001_111E"), {'for': 'state:*'})
    census_pd = pd.DataFrame(census_data)
    census_pd = census_pd.rename(columns={"NAME": "Name",
                                          "B16001_002E":"English only", 
                                          "B16001_003E":"Spanish", 
                                          "B16001_009E":"French",
                                          "B16001_021E":"Yaddish",
                                          "B16001_009E": "French Creole",
                                          "B16001_012E": "Italian",
                                          "B16001_015E": "Portuguese",
                                          "B16001_018E": "German",
                                          "B16001_030E": "Greek",
                                          "B16001_033E": "Russian",
                                          "B16001_036E": "Polish",
                                          "B16001_039E": "Serbo-Croatian",
                                          "B16001_045E": "Armenian",
                                          "B16001_048E": "Persian",
                                          "B16001_051E": "Gujarati",
                                          "B16001_054E": "Hindi",
                                          "B16001_057E": "Urdu",
                                          "B16001_066E": "Chinese",
                                          "B16001_069E": "Japanese",
                                          "B16001_072E": "Korean",
                                          "B16001_075E": "Mon-Khmer",
                                          "B16001_078E": "Hmong",
                                          "B16001_081E": "Thai",
                                          "B16001_084E": "Laotian",
                                          "B16001_087E": "Vietnamese",
                                          "B16001_093E": "Tagalog",
                                          "B16001_099E": "Navajo",
                                          "B16001_105E": "Hungarian",
                                          "B16001_108E": "Arabic",
                                          "B16001_111E": "Hebrew"})
    #census_pd.append(census_pd.sum(numeric_only=True), ignore_index=True)
    census_pd.to_csv(f"{year}_census.csv",index = None, header=True)

# %%
# Print out each year's census data individually
years = [2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
for year in years:
    c = Census(census_api_key, year)
    census(c,year)

# %%
census_files = sorted(glob("*_census.csv"))
census_files
# Out:
# ['2009_census.csv',
#  '2010_census.csv',
#  '2011_census.csv',
#  '2012_census.csv',
#  '2013_census.csv',
#  '2014_census.csv',
#  '2015_census.csv',
#  '2016_census.csv',
#  '2017_census.csv',
#  '2018_census.csv']

# %%
census_df = pd.concat((pd.read_csv(file).assign(Year=file) 
                       for file in census_files),ignore_index=True)

census_df = census_df.replace("2009_census.csv","2009")
census_df = census_df.replace("2010_census.csv","2010")
census_df = census_df.replace("2011_census.csv","2011")
census_df = census_df.replace("2012_census.csv","2012")
census_df = census_df.replace("2013_census.csv","2013")
census_df = census_df.replace("2014_census.csv","2014")
census_df = census_df.replace("2015_census.csv","2015")
census_df = census_df.replace("2016_census.csv","2016")
census_df = census_df.replace("2017_census.csv","2017")
census_df = census_df.replace("2018_census.csv","2018")

census_df = census_df.sort_values(["Name","Year"])
census_df = census_df.reset_index(drop=True)
census_df
# Out:
#         Name  English only   Spanish  French Creole  Yaddish  Italian  \
# 0    Alabama     4137110.0  113179.0          438.0     23.0   1796.0
# 1    Alabama     4194045.0  137617.0          568.0     29.0   1638.0
# 2    Alabama     4219401.0  144390.0          293.0      9.0   1821.0
# 3    Alabama     4241429.0  149070.0          338.0     20.0   1790.0
# 4    Alabama     4261611.0  151384.0          333.0     18.0   1672.0
# ..       ...           ...       ...            ...      ...      ...
# 515  Wyoming      499332.0   26150.0            2.0      0.0    331.0
# 516  Wyoming      502352.0   27635.0            3.0      0.0    302.0
# 517  Wyoming      505407.0   27245.0           62.0    130.0    395.0
# 518  Wyoming      506060.0   27302.0           79.0    131.0    401.0
# 519  Wyoming      504841.0   27564.0           37.0    178.0    375.0
#
#      Portuguese   German   Greek  Russian  ...   Thai  Laotian  Vietnamese  \
# 0        1294.0  10230.0  1003.0   1467.0  ...  876.0    921.0      5256.0
# 1        1293.0  10017.0   967.0   1327.0  ...  757.0    904.0      5716.0
# 2        1294.0  10335.0   841.0   1305.0  ...  962.0    726.0      6258.0
# 3        1326.0  10069.0   878.0   1268.0  ...  835.0    802.0      6337.0
# 4        1374.0  10038.0   918.0   1325.0  ...  828.0    935.0      6839.0
# ..          ...      ...     ...      ...  ...    ...      ...         ...
# 515       359.0   1539.0   146.0    401.0  ...  159.0      1.0       206.0
# 516       295.0   1504.0    97.0    395.0  ...  224.0      3.0       350.0
# 517       248.0   2005.0    43.0     52.0  ...  412.0     37.0       271.0
# 518       127.0   2050.0    35.0     31.0  ...  347.0     30.0       161.0
# 519       117.0   1977.0     0.0     21.0  ...  366.0      4.0        69.0
#
#      Tagalog  Navajo  Hungarian  Arabic  Hebrew  state  Year
# 0     2141.0    39.0      154.0  4090.0   325.0      1  2009
# 1     2546.0    45.0      154.0  3889.0   510.0      1  2010
# 2     2947.0    30.0      135.0  3656.0   593.0      1  2011
# 3     3025.0    79.0      132.0  3807.0   471.0      1  2012
# 4     3115.0    96.0      145.0  4560.0   410.0      1  2013
# ..       ...     ...        ...     ...     ...    ...   ...
# 515    716.0   149.0       73.0   200.0     9.0     56  2014
# 516    605.0   142.0       92.0   242.0    18.0     56  2015
# 517    156.0   684.0      368.0    18.0    82.0     56  2016
# 518    153.0   798.0      415.0    17.0    86.0     56  2017
# 519    147.0   780.0      416.0    17.0    61.0     56  2018
#
# [520 rows x 32 columns]

# %%
census_df.to_csv("combined_data.csv",index = None, header=True)
