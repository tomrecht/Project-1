# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
census_data = pd.read_csv('SumsByYear.csv')
census_data = census_data.iloc[:,:8]
census_data.rename(columns = {'Unnamed: 0':'Language'}, inplace = True)
census_data.head()
# Out:
#         Language         2009         2010         2011         2012  \
# 0   English only  225882277.0  226897366.0  228376880.0  229781216.0
# 1        Spanish   37574942.0   38833955.0   39519093.0   40160868.0
# 2  French Creole     612910.0     656051.0     688785.0     713701.0
# 3        Yiddish     159410.0     154342.0     154977.0     156136.0
# 4        Italian     804455.0     765684.0     747740.0     733340.0
#
#           2013         2014         2015
# 0  231294617.0  232900575.0  234352363.0
# 1   40750580.0   41351012.0   41895668.0
# 2     739768.0     765985.0     786770.0
# 3     155582.0     157943.0     159695.0
# 4     709354.0     689586.0     663629.0

# %%
navajo = census_data[census_data["Language"] == "Navajo"]
#cap_mouse = cap[cap["Mouse ID"] == "b128"]
navajo = navajo.loc[:,:]
navajo.set_index(['Language'], inplace=True)
navajo_rev = navajo.T
navajo_rev
# Out:
# Language    Navajo
# 2009      170744.0
# 2010      169471.0
# 2011      168146.0
# 2012      168266.0
# 2013      166826.0
# 2014      166123.0
# 2015      163169.0

# %%
navajo_rev.plot(kind="bar",  rot=45, figsize=(7,3))
plt.title("The Navajo - Speaking Population from 2009 to 2015")
plt.ylim(150000, 175000)
plt.show()
plt.tight_layout()
plt.savefig("Fig1.png")
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
census_2018 = pd.read_csv('2018.csv')
census_2018 = census_2018.iloc[:,:-1]
census_2018.head()
# Out:
#           Name  English only   Spanish  French Creole  Yiddish  Italian  \
# 0    Minnesota     4571735.0  200863.0         1572.0   3005.0   1921.0
# 1  Mississippi     2691455.0   68037.0          345.0    653.0    764.0
# 2     Missouri     5367705.0  145831.0         1098.0  10553.0   3395.0
# 3      Montana      939716.0   14762.0           59.0    752.0    528.0
# 4     Nebraska     1574067.0  131151.0          174.0    583.0    616.0
#
#    Portuguese   German   Greek  Russian  ...  Mon-Khmer   Hmong    Thai  \
# 0      3376.0  19475.0  2655.0   4198.0  ...    23981.0  3885.0  5333.0
# 1       708.0   2515.0   328.0     26.0  ...     3700.0   927.0  1295.0
# 2      2583.0  19451.0  1718.0  12585.0  ...    21988.0  2618.0  6803.0
# 3       323.0   6418.0   191.0    106.0  ...     1378.0   526.0   502.0
# 4      1029.0   4337.0   600.0    978.0  ...     4887.0  1317.0  1570.0
#
#    Laotian  Vietnamese  Tagalog  Navajo  Hungarian  Arabic   Hebrew
# 0  62881.0     23106.0   9660.0  7331.0    13635.0  1107.0  77738.0
# 1     36.0      5725.0    302.0  2843.0     2920.0   175.0    295.0
# 2   1403.0     13451.0   2218.0  7618.0    12539.0   871.0   6356.0
# 3     18.0       284.0    301.0  1093.0      425.0   314.0     39.0
# 4    225.0      6961.0   1644.0  1744.0     5387.0    73.0   3505.0
#
# [5 rows x 30 columns]

# %%
census_2018.rename(columns = {'Name':'State'}, inplace = True)
census_navajo = census_2018.loc[:, ["State","Navajo"]]
census_navajo = census_navajo.sort_values(by='Navajo', ascending=False)
#navajo_summary = census_navajo.iloc[0:5]
census_navajo.set_index(['State'], inplace=True)
census_navajo = census_navajo.iloc[0:5]
census_navajo
# Out:
#               Navajo
# State
# California  798884.0
# Texas        83962.0
# Illinois     81617.0
# Nevada       79356.0
# New Jersey   77800.0

# %%
census_navajo.plot(kind="bar",  rot=45, figsize=(7,3))
plt.title("The five states use the Navajo language the most in 2018")
plt.show()
plt.tight_layout()
plt.savefig("Fig2.png")
# Out:
# <img src="data:image/png;base64,..." width="700">
