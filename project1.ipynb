# %%
# Dependencies
from census import Census
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

# %%
# Census API Key
census_api_key = "85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98"

# %%
def census(c,year):
    census_data = c.acs5.get(("NAME", "B16001_002E", "B16001_003E", "B16001_009E",
                          "B16001_021E","B16001_009E","B16001_012E","B16001_015E","B16001_018E",
                          "B16001_030E","B16001_033E","B16001_036E","B16001_039E","B16001_045E",
                          "B16001_048E","B16001_051E","B16001_054E","B16001_057E","B16001_066E",
                          "B16001_069E","B16001_072E","B16001_075E","B16001_078E","B16001_081E",
                          "B16001_084E","B16001_087E","B16001_093E","B16001_099E","B16001_105E",
                          "B16001_105E","B16001_108E","B16001_111E"), {'for': 'state:*'})
    census_pd = pd.DataFrame(census_data)
    census_pd = census_pd.rename(columns={"NAME": "Name",
                                          "B16001_002E":"English only", 
                                          "B16001_003E":"Spanish", 
                                          "B16001_009E":"French",
                                          "B16001_021E":"Yaddish",
                                          "B16001_009E": "French Creole",
                                          "B16001_012E": "Italian",
                                          "B16001_015E": "Portuguese",
                                          "B16001_018E": "German",
                                          "B16001_030E": "Greek",
                                          "B16001_033E": "Russian",
                                          "B16001_036E": "Polish",
                                          "B16001_039E": "Serbo-Croatian",
                                          "B16001_045E": "Armenian",
                                          "B16001_048E": "Persian",
                                          "B16001_051E": "Gujarati",
                                          "B16001_054E": "Hindi",
                                          "B16001_057E": "Urdu",
                                          "B16001_066E": "Chinese",
                                          "B16001_069E": "Japanese",
                                          "B16001_072E": "Korean",
                                          "B16001_075E": "Mon-Khmer",
                                          "B16001_078E": "Hmong",
                                          "B16001_081E": "Thai",
                                          "B16001_084E": "Laotian",
                                          "B16001_087E": "Vietnamese",
                                          "B16001_093E": "Tagalog",
                                          "B16001_099E": "Navajo",
                                          "B16001_105E": "Hungarian",
                                          "B16001_108E": "Arabic",
                                          "B16001_111E": "Hebrew"})
    #census_pd.append(census_pd.sum(numeric_only=True), ignore_index=True)
    census_pd.to_csv(f"{year}_census.csv",index = None, header=True)

# %%
# Print out each year's census data individually
years = [2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
for year in years:
    c = Census(census_api_key, year)
    census(c,year)

# %%
census_files = sorted(glob("*_census.csv"))
census_files
# Out:
# ['2009_census.csv',
#  '2010_census.csv',
#  '2011_census.csv',
#  '2012_census.csv',
#  '2013_census.csv',
#  '2014_census.csv',
#  '2015_census.csv',
#  '2016_census.csv',
#  '2017_census.csv',
#  '2018_census.csv']

# %%
census_df = pd.concat((pd.read_csv(file).assign(Year=file) 
                       for file in census_files),ignore_index=True)

census_df = census_df.replace("2009_census.csv","2009")
census_df = census_df.replace("2010_census.csv","2010")
census_df = census_df.replace("2011_census.csv","2011")
census_df = census_df.replace("2012_census.csv","2012")
census_df = census_df.replace("2013_census.csv","2013")
census_df = census_df.replace("2014_census.csv","2014")
census_df = census_df.replace("2015_census.csv","2015")
census_df = census_df.replace("2016_census.csv","2016")
census_df = census_df.replace("2017_census.csv","2017")
census_df = census_df.replace("2018_census.csv","2018")

census_df.sort_values(["Name","Year"],ascending = True)
census_df = census_df.reset_index(drop=True)
census_df
# Out:
#               Name  English only    Spanish  French Creole  Yaddish  Italian  \
# 0           Alaska      533451.0    22735.0          177.0      0.0    376.0
# 1          Alabama     4137110.0   113179.0          438.0     23.0   1796.0
# 2         Arkansas     2472084.0   122443.0           56.0     33.0   1091.0
# 3          Arizona     4200786.0  1261134.0          349.0    358.0   7982.0
# 4       California    19409485.0  9462163.0         5847.0   5129.0  66665.0
# ..             ...           ...        ...            ...      ...      ...
# 515      Louisiana     4001758.0   161432.0         5694.0    643.0   1964.0
# 516          Maine     1188798.0    11461.0          364.0    694.0    968.0
# 517       Maryland     4599111.0   450150.0        14401.0   3955.0   8267.0
# 518  Massachusetts     4941922.0   581553.0        81696.0   3877.0  32444.0
# 519       Michigan     8486297.0   279967.0         1396.0  10822.0  15143.0
#
#      Portuguese    German    Greek   Russian  ...     Thai  Laotian  \
# 0         419.0    3689.0     75.0    3688.0  ...    805.0    780.0
# 1        1294.0   10230.0   1003.0    1467.0  ...    876.0    921.0
# 2         697.0    5997.0    241.0     629.0  ...    286.0   3101.0
# 3        3032.0   22953.0   2628.0    7888.0  ...   2157.0   1977.0
# 4       76778.0  118367.0  24310.0  142981.0  ...  42824.0  36245.0
# ..          ...       ...      ...       ...  ...      ...      ...
# 515      2894.0    4734.0    455.0     909.0  ...   2734.0     68.0
# 516      1538.0    2846.0    642.0     550.0  ...    430.0      0.0
# 517     12758.0   15956.0   4341.0    1730.0  ...  38017.0    110.0
# 518    190569.0   15202.0  15998.0    4213.0  ...  15802.0    427.0
# 519      5338.0   32315.0  19000.0   12407.0  ...  15463.0   5034.0
#
#      Vietnamese   Tagalog   Navajo  Hungarian    Arabic   Hebrew  state  Year
# 0        1031.0   12897.0    166.0       88.0     500.0    150.0      2  2009
# 1        5256.0    2141.0     39.0      154.0    4090.0    325.0      1  2009
# 2        4278.0    2131.0     17.0      206.0    2053.0    240.0      5  2009
# 3       16634.0   16083.0  87943.0     1904.0   12464.0   1385.0      4  2009
# 4      457012.0  699611.0   1573.0    15014.0  128659.0  39519.0      6  2009
# ..          ...       ...      ...        ...       ...      ...    ...   ...
# 515     28941.0    2820.0   5173.0     9834.0     421.0    786.0     22  2018
# 516      1159.0     441.0   1455.0     2508.0     121.0   2462.0     23  2018
# 517     21932.0    4745.0  33448.0    18158.0    5734.0  30888.0     24  2018
# 518     41976.0    5822.0   8327.0    35090.0    7086.0  11128.0     25  2018
# 519     14373.0    5159.0  16348.0   138749.0    2191.0  33265.0     26  2018
#
# [520 rows x 32 columns]

# %%
census_df.to_csv("combined_census.csv",index = None, header=True)
