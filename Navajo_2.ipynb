# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
census_data = pd.read_csv('SumsByYear.csv')
census_data = census_data.iloc[:,:8]
census_data.rename(columns = {'Unnamed: 0':'Language'}, inplace = True)
census_data.head()
# Out:
#         Language         2009         2010         2011         2012  \
# 0   English only  225882277.0  226897366.0  228376880.0  229781216.0
# 1        Spanish   37574942.0   38833955.0   39519093.0   40160868.0
# 2  French Creole     612910.0     656051.0     688785.0     713701.0
# 3        Yiddish     159410.0     154342.0     154977.0     156136.0
# 4        Italian     804455.0     765684.0     747740.0     733340.0
#
#           2013         2014         2015
# 0  231294617.0  232900575.0  234352363.0
# 1   40750580.0   41351012.0   41895668.0
# 2     739768.0     765985.0     786770.0
# 3     155582.0     157943.0     159695.0
# 4     709354.0     689586.0     663629.0

# %%
navajo = census_data[census_data["Language"] == "Navajo"]
#cap_mouse = cap[cap["Mouse ID"] == "b128"]
navajo = navajo.loc[:,:]
navajo.set_index(['Language'], inplace=True)
navajo_rev = navajo.T
navajo_rev
# Out:
# Language    Navajo
# 2009      170744.0
# 2010      169471.0
# 2011      168146.0
# 2012      168266.0
# 2013      166826.0
# 2014      166123.0
# 2015      163169.0

# %%
navajo_rev.plot(kind="bar",  rot=45, figsize=(7,3))
plt.title("The Navajo - Speaking Population from 2009 to 2015")
plt.ylim(150000, 175000)
plt.show()
plt.xlabel("Years")
plt.ylabel("Number of Speakers")
plt.tight_layout()
plt.savefig("SpeakingPopulation.png")
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
census_2015 = pd.read_csv('2015.csv')
census_2015 = census_2015.iloc[:,:-1]
census_2015.head()
# Out:
#          Name  English only     Spanish  French Creole  Yiddish  Italian  \
# 0     Alabama     4300026.0    150337.0          698.0     48.0   1459.0
# 1      Alaska      568544.0     23555.0          181.0      3.0    337.0
# 2     Arizona     4536673.0   1272191.0          769.0    449.0   7010.0
# 3    Arkansas     2566546.0    144270.0          119.0     23.0    786.0
# 4  California    20142054.0  10329154.0         7071.0   3062.0  60355.0
#
#    Portuguese    German    Greek   Russian  ...  Mon-Khmer    Hmong     Thai  \
# 0      1274.0    9073.0    670.0    1615.0  ...      749.0    286.0   1163.0
# 1       163.0    3185.0    145.0    4758.0  ...      193.0   3598.0   1120.0
# 2      3919.0   22354.0   3162.0    8044.0  ...     1856.0    253.0   3117.0
# 3       809.0    5268.0    188.0     734.0  ...      354.0   1436.0    672.0
# 4     77729.0  107874.0  24694.0  156323.0  ...    77845.0  74530.0  47156.0
#
# ...

# %%
census_2015.rename(columns = {'Name':'State'}, inplace = True)
census_navajo = census_2015.loc[:, ["State","Navajo"]]
census_navajo = census_navajo.sort_values(by='Navajo', ascending=False)
#navajo_summary = census_navajo.iloc[0:5]
census_navajo.set_index(['State'], inplace=True)
census_navajo = census_navajo.iloc[0:5]
census_navajo
# Out:
#              Navajo
# State
# Arizona     82956.0
# New Mexico  62707.0
# Utah         7343.0
# Colorado     2449.0
# California   1343.0

# %%
census_navajo.plot(kind="bar",  rot=45, figsize=(7,3))
plt.title("The five states use the Navajo language the most in 2015")
plt.xlabel("States")
plt.ylabel("Number of Speakers")
plt.show()
plt.tight_layout()
plt.savefig("States.png")
# Out:
# <img src="data:image/png;base64,..." width="700">
